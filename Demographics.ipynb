# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sms
df=pd.read_csv('../bids/subjects.tsv',sep='\t')
plt.rcParams['svg.fonttype'] = 'none'

sms.set_context("paper")

df=df.drop_duplicates()
len(df)
# Out:
# 284

# %%
df['Age']=df['age']
df['Sex']=df['sex']
df['Total AQ']=df['AQ_total']
sms.histplot(x='Age',hue='Sex',data=df,kde=True,hue_order=['Male','Female','Other'])
plt.savefig("Figures/Demographics_inPerson.svg")
plt.show()
# Out:
# /home/strange/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sms.histplot(x='Total AQ',hue='Sex',data=df,kde=True,hue_order=['Male','Female','Other'])
plt.savefig("Figures/Demographics_OnLine.svg")
plt.show()
# Out:
# /home/strange/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#df=pd.read_csv('prolific_export_645429988b4933c945101127(3).csv')
df.columns
# Out:
# Index(['sub', 'USIDep', 'AQ_Social', 'AQ_AttnDet', 'AQ_AttnSwitch',
#        'AQ_Commun', 'AQ_Imagine', 'AQ_total', 'none', 'age', 'sex', 'sexOther',
#        'race', 'raceOther', 'education', 'zip1', 'zip5', 'none_2', 'SFQ1',
#        'SFQ2', 'SFQ3', 'SFQ4', 'SFQ5', 'SFQ6', 'SFQ7', 'FEVS_1', 'FEVS_2',
#        'FEVS_3', 'FEVS_4', 'FEVS_5', 'FEVS_6', 'FEVS_7', 'FEVS_8', 'FEVS_9',
#        'SUSD1', 'SUSD2', 'SUSD3', 'SUSD4', 'SUSD5', 'SUSD6', 'SUSD7', 'SUSD8',
#        'SUSD9', 'SUSD10', 'SUSD11', 'SUSD12', 'SUSD13', 'SUSD14', 'AADIS1',
#        'AADIS2', 'AADIS4', 'AADIS4.1', 'AADIS5', 'AADIS6', 'AADIS7', 'AADIS8',
#        'AADIS9', 'AADIS10', 'AADIS11', 'AADIS12', 'Age', 'Sex', 'Total AQ'],
#       dtype='object')

# %%
#df=df[df['sub'].isin(subs)]

# %%
for col in ['sex','race','education']:
    for val in df[col].unique():
        print(col,val,len(df[df[col]==val]),len(df[df[col]==val])/len(df))
# Out:
# sex Female 140 0.49295774647887325
# sex Male 143 0.5035211267605634
# sex Other 1 0.0035211267605633804
# race Black or African American 32 0.11267605633802817
# race White / Caucasian 207 0.7288732394366197
# race Multiple ethnicity/ Other (please specify) 8 0.028169014084507043
# race Asian / Pacific Islander 21 0.07394366197183098
# race  Hispanic 15 0.0528169014084507
# race Native American or Alaskan Native 1 0.0035211267605633804
# education Some college credit, no degree 60 0.2112676056338028
# education Bachelor's Degree 99 0.3485915492957746
# education Master's Degree 42 0.14788732394366197
# education Associates Degree 31 0.10915492957746478
# education High school graduate, diploma or the equivalent 40 0.14084507042253522
# education Doctoral Degree 8 0.028169014084507043
# education Some high school, no diploma 4 0.014084507042253521

# %%
pd.crosstab(df['education'],df['race'])
# Out:
# race                                              Hispanic  \
# education
# Associates Degree                                        3
# Bachelor's Degree                                        8
# Doctoral Degree                                          0
# High school graduate, diploma or the equivalent          1
# Master's Degree                                          0
# Some college credit, no degree                           3
# Some high school, no diploma                             0
#
# race                                             Asian / Pacific Islander  \
# education
# Associates Degree                                                       2
# Bachelor's Degree                                                       9
# Doctoral Degree                                                         1
# High school graduate, diploma or the equivalent                         2
# Master's Degree                                                         4
# ...
