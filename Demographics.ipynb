# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sms
os.listdir('.')
# Out:
# ['Hypothesis_3.ipynb',
#  '.ipynb_checkpoints',
#  'Make_bids.ipynb',
#  'Predictions',
#  'Hypothesis_2.ipynb',
#  'Figures_H2a.svg',
#  'Figures_H2a.png',
#  'Demographics.ipynb',
#  'Figures',
#  'axes_1.png',
#  'prolific_export_645429988b4933c945101127(3).csv',
#  '.git',
#  'Hypthesis 1.ipynb',
#  'LICENSE',
#  'README.md']

# %%
df=pd.read_csv('prolific_export_645429988b4933c945101127(3).csv')
display(df)
df=df[df['Sex']!='CONSENT_REVOKED']
df['Age']=df['Age'].astype('int')
plt.figure(figsize=(16, 6))
sms.histplot(x='Age',hue='Sex',data=df,kde=True)
plt.show()
# Out:
#                 Submission id            Participant id           Status  \
# 0    645a4c5a46c6e8bd4348748d  5d793a152df8ed001645ed7f         APPROVED
# 1    645a4e493566b646c93de231  5731e4005b8b06000f7e36b3         APPROVED
# 2    645a4e8066d382afb4cedc9e  5bd6656a669ee1000145304a         APPROVED
# 3    645a4eff28847d3c77e3d4ac  63d4d6434407b2b392e65863         APPROVED
# 4    645a4f6c404924ae3aef6c92  56a3d5f951212a000d64c2b9         APPROVED
# ..                        ...                       ...              ...
# 301  645ebf97c1177c55d4d67cec  63eb78a1fc614fd7af392873         APPROVED
# 302  645ebfbd4611c10b83d7d2f2  59e62b6277860e0001512e14         APPROVED
# 303  645ec5ac6a79d3b341801d75  62ff26509176c97c9ceebc2b         APPROVED
# 304  6463f198d5d74bb44d805bf5  5eb087ed7f6d1e1232690d6a         APPROVED
# 305  64698469c85e1730ec1f35ba  63b7992d848592c307fe1e49  AWAITING REVIEW
#
#                       Started at                 Completed at  \
# ...
